# %%
# if running this is something like google colab first uncomment and run below to install latest version of netdata-pandas
#!pip install --upgrade netdata-pandas

# %%
from netdata_pandas.data import get_data

# %% [markdown]
# Lets pull some data from our two demo servers into a pandas dataframe.

# %%
hosts = ['london.my-netdata.io', 'newyork.my-netdata.io']
charts = ['system.cpu', 'system.load']
after = -60
before = 0

df = get_data(hosts, charts, after, before)
print(df.shape)
df.head()
# Out:
# (121, 24)
#                                  system.load|load1  system.load|load5  \
# host                 time_idx
# london.my-netdata.io 1592308920               0.47               0.16
#                      1592308924               0.47               0.16
#                      1592308925               0.43               0.16
#                      1592308926               0.43               0.16
#                      1592308927               0.43               0.16
#
#                                  system.load|load15  system.cpu|guest_nice  \
# host                 time_idx
# london.my-netdata.io 1592308920                0.06                    NaN
#                      1592308924                0.06                    0.0
#                      1592308925                0.06                    0.0
#                      1592308926                0.06                    0.0
#                      1592308927                0.06                    0.0
#
#                                  system.cpu|guest  system.cpu|steal  \
# host                 time_idx
# london.my-netdata.io 1592308920               NaN               NaN
#                      1592308924               0.0               0.0
#                      1592308925               0.0               0.0
#                      1592308926               0.0               0.0
#                      1592308927               0.0               0.0
#
#                                  system.cpu|softirq  system.cpu|irq  \
# host                 time_idx
# london.my-netdata.io 1592308920                 NaN             NaN
#                      1592308924            0.000000             0.0
#                      1592308925            0.000000             0.0
#                      1592308926            0.000000             0.0
#                      1592308927            0.251256             0.0
#
#                                  system.cpu|user  system.cpu|system  ...  \
# host                 time_idx                                        ...
# london.my-netdata.io 1592308920              NaN                NaN  ...
#                      1592308924         0.506329           0.253165  ...
#                      1592308925         0.753769           1.256281  ...
#                      1592308926         1.005025           0.251256  ...
#                      1592308927         1.256281           1.005025  ...
#
#                                  system.load|load15  system.cpu|guest_nice  \
# host                 time_idx
# london.my-netdata.io 1592308920                 NaN                    NaN
#                      1592308924                 NaN                    NaN
#                      1592308925                 NaN                    NaN
#                      1592308926                 NaN                    NaN
#                      1592308927                 NaN                    NaN
#
#                                  system.cpu|guest  system.cpu|steal  \
# host                 time_idx
# london.my-netdata.io 1592308920               NaN               NaN
#                      1592308924               NaN               NaN
#                      1592308925               NaN               NaN
#                      1592308926               NaN               NaN
#                      1592308927               NaN               NaN
#
#                                  system.cpu|softirq  system.cpu|irq  \
# host                 time_idx
# london.my-netdata.io 1592308920                 NaN             NaN
#                      1592308924                 NaN             NaN
#                      1592308925                 NaN             NaN
#                      1592308926                 NaN             NaN
#                      1592308927                 NaN             NaN
#
#                                  system.cpu|user  system.cpu|system  \
# host                 time_idx
# london.my-netdata.io 1592308920              NaN                NaN
#                      1592308924              NaN                NaN
#                      1592308925              NaN                NaN
#                      1592308926              NaN                NaN
#                      1592308927              NaN                NaN
#
#                                  system.cpu|nice  system.cpu|iowait
# host                 time_idx
# london.my-netdata.io 1592308920              NaN                NaN
#                      1592308924              NaN                NaN
#                      1592308925              NaN                NaN
#                      1592308926              NaN                NaN
#                      1592308927              NaN                NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Lets have a look at some timings in pulling this data.

# %%
# %%timeit

df = get_data(hosts, charts, after, before)
# Out:
# 225 ms ± 14.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# If we wanted to pull data for all charts we can do something like this.

# %%
df = get_data('london.my-netdata.io', ['all'], after, before)
print(df.shape)
df.head()
# Out:
# (69, 2091)
#             users.lwrites|ulog  users.lwrites|messagebus  users.lwrites|unscd  \
# time_idx
# 1592308920                 NaN                       NaN                  NaN
# 1592308925                 NaN                       NaN                  NaN
# 1592308926                 0.0                       0.0             0.000000
# 1592308927                 0.0                       0.0             0.315427
# 1592308928                 0.0                       0.0             0.000000
#
#             users.lwrites|bind  users.lwrites|nobody  users.lwrites|ntp  \
# time_idx
# 1592308920                 NaN                   NaN                NaN
# 1592308925                 NaN                   NaN                NaN
# 1592308926                 0.0                   0.0                0.0
# 1592308927                 0.0                   0.0                0.0
# 1592308928                 0.0                   0.0                0.0
#
#             users.lwrites|postfix  users.lwrites|mysql  \
# time_idx
# 1592308920                    NaN                  NaN
# 1592308925                    NaN                  NaN
# 1592308926               0.000000                  0.0
# 1592308927               0.024512                  0.0
# 1592308928               0.000000                  0.0
#
#             users.lwrites|www-data  users.lwrites|netdata  ...  \
# time_idx                                                   ...
# 1592308920                     NaN                    NaN  ...
# 1592308925                     NaN                    NaN  ...
# 1592308926                40.29840               19.14503  ...
# 1592308927                79.51077               21.24856  ...
# 1592308928                41.16272               25.57774  ...
#
#             netdata.runtime_postfix_local|run time  \
# time_idx
# 1592308920                                     NaN
# 1592308925                                     NaN
# 1592308926                                     NaN
# 1592308927                                     NaN
# 1592308928                                     NaN
#
#            netdata.runtime_ntpd_local|run time netdata.apps_fix|utime  \
# time_idx
# 1592308920                                 NaN                    NaN
# 1592308925                                 NaN                    NaN
# 1592308926                                 NaN                    NaN
# 1592308927                                 NaN                    NaN
# 1592308928                                 NaN                    NaN
#
#             netdata.apps_fix|stime  netdata.apps_fix|gtime  \
# time_idx
# 1592308920                     NaN                     NaN
# 1592308925                     NaN                     NaN
# 1592308926                     NaN                     NaN
# 1592308927                     NaN                     NaN
# 1592308928                     NaN                     NaN
#
#             netdata.apps_fix|minflt  netdata.apps_fix|majflt  \
# time_idx
# 1592308920                      NaN                      NaN
# 1592308925                      NaN                      NaN
# 1592308926                      NaN                      NaN
# 1592308927                      NaN                      NaN
# 1592308928                      NaN                      NaN
#
#             netdata.runtime_web_log_nginx|run time  \
# time_idx
# 1592308920                                     NaN
# 1592308925                                     NaN
# 1592308926                                     NaN
# 1592308927                                     NaN
# 1592308928                                     NaN
#
#             web_log_nginx.clients_all|ipv4  web_log_nginx.clients_all|ipv6
# time_idx
# 1592308920                             NaN                             NaN
# 1592308925                             NaN                             NaN
# 1592308926                             NaN                             NaN
# 1592308927                             NaN                             NaN
# 1592308928                             NaN                             NaN
#
# [5 rows x 2091 columns]

# %% [markdown]
# Similar to above but lets add some flags to throw away columns we are probably not interested in.

# %%
after = -60*5
before = 0

df = get_data('london.my-netdata.io', ['all'], after, before, numeric_only=True, nunique_thold=0.05)
print(df.shape)
df.head()
# Out:
# (307, 536)
#             users.lwrites|ulog  users.lwrites|www-data  users.lwrites|netdata  \
# time_idx
# 1592308690                 NaN                     NaN                    NaN
# 1592308693                 0.0                51.48505              24.892370
# 1592308694                 0.0                49.29439              18.499830
# 1592308695                 0.0                63.12931              14.630437
# 1592308696                 0.0                42.84438              18.275240
#
#             users.lwrites|root  users.sockets|www-data  \
# time_idx
# 1592308690                 NaN                     NaN
# 1592308693            17.44316                   256.0
# 1592308694            17.49750                   260.0
# 1592308695            17.50731                   262.0
# 1592308696            17.66197                   265.0
#
#             users.cpu_system|mysql  users.cpu_system|www-data  \
# time_idx
# 1592308690                     NaN                        NaN
# 1592308693                  0.6212                     0.0000
# 1592308694                  0.0000                     0.0000
# 1592308695                  0.0000                     0.6265
# 1592308696                  0.7142                     0.0000
#
#             users.cpu_system|netdata  users.cpu_system|root  \
# time_idx
# 1592308690                       NaN                    NaN
# 1592308693                    0.6212                 1.2449
# 1592308694                    0.9999                 1.9998
# 1592308695                    1.2531                 0.6290
# 1592308696                    0.7142                 1.4284
#
#             groups.lreads|www-data  ...  groups.uptime|www-data  \
# time_idx                            ...
# 1592308690                     NaN  ...                     NaN
# 1592308693               16.459421  ...                     NaN
# 1592308694               16.179808  ...                     NaN
# 1592308695                0.820305  ...                     NaN
# 1592308696                0.410153  ...                     NaN
#
#             groups.uptime|netdata  groups.uptime|root  users.cpu_user|mysql  \
# time_idx
# 1592308690                    NaN                 NaN                   NaN
# 1592308693                    NaN                 NaN                   NaN
# 1592308694                    NaN                 NaN                   NaN
# 1592308695                    NaN                 NaN                   NaN
# 1592308696                    NaN                 NaN                   NaN
#
#             users.cpu_user|www-data  users.cpu_user|netdata  \
# time_idx
# 1592308690                      NaN                     NaN
# 1592308693                      NaN                     NaN
# 1592308694                      NaN                     NaN
# 1592308695                      NaN                     NaN
# 1592308696                      NaN                     NaN
#
#             users.cpu_user|root  users.pwrites|www-data  \
# time_idx
# 1592308690                  NaN                     NaN
# 1592308693                  NaN                     NaN
# 1592308694                  NaN                     NaN
# 1592308695                  NaN                     NaN
# 1592308696                  NaN                     NaN
#
#             users.pwrites|netdata  users.pwrites|root
# time_idx
# 1592308690                    NaN                 NaN
# 1592308693                    NaN                 NaN
# 1592308694                    NaN                 NaN
# 1592308695                    NaN                 NaN
# 1592308696                    NaN                 NaN
#
# [5 rows x 536 columns]
