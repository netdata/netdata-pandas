# %%
# if running this is something like google colab first uncomment and run below to install latest version of netdata-pandas
#!pip install --upgrade netdata-pandas

# %%
from netdata_pandas.data import get_data

# %% [markdown]
# Lets pull some data from our two demo servers into a pandas dataframe.

# %%
hosts = ['london.my-netdata.io', 'newyork.my-netdata.io']
charts = ['system.cpu', 'system.load']
after = -60
before = 0

df = get_data(hosts, charts, after, before)
print(df.shape)
df.head()
# Out:
# (120, 24)
#                                  system.cpu|guest_nice  system.cpu|guest  \
# host                 time_idx
# london.my-netdata.io 1592303468                    0.0               0.0
#                      1592303469                    0.0               0.0
#                      1592303470                    0.0               0.0
#                      1592303471                    0.0               0.0
#                      1592303472                    0.0               0.0
#
#                                  system.cpu|steal  system.cpu|softirq  \
# host                 time_idx
# london.my-netdata.io 1592303468               0.0            0.000000
#                      1592303469               0.0            0.252525
#                      1592303470               0.0            0.000000
#                      1592303471               0.0            0.000000
#                      1592303472               0.0            0.000000
#
#                                  system.cpu|irq  system.cpu|user  \
# host                 time_idx
# london.my-netdata.io 1592303468             0.0         0.502513
#                      1592303469             0.0         0.252525
#                      1592303470             0.0         0.751880
#                      1592303471             0.0         0.502513
#                      1592303472             0.0         0.503778
#
#                                  system.cpu|system  system.cpu|nice  \
# host                 time_idx
# london.my-netdata.io 1592303468           0.753769              0.0
#                      1592303469           0.252525              0.0
#                      1592303470           0.751880              0.0
#                      1592303471           0.502513              0.0
#                      1592303472           0.755668              0.0
#
#                                  system.cpu|iowait  system.load|load1  ...  \
# host                 time_idx                                          ...
# london.my-netdata.io 1592303468                0.0                NaN  ...
#                      1592303469                0.0                NaN  ...
#                      1592303470                0.0                NaN  ...
#                      1592303471                0.0                NaN  ...
#                      1592303472                0.0                NaN  ...
#
#                                  system.cpu|steal  system.cpu|softirq  \
# host                 time_idx
# london.my-netdata.io 1592303468               NaN                 NaN
#                      1592303469               NaN                 NaN
#                      1592303470               NaN                 NaN
#                      1592303471               NaN                 NaN
#                      1592303472               NaN                 NaN
#
#                                  system.cpu|irq  system.cpu|user  \
# host                 time_idx
# london.my-netdata.io 1592303468             NaN              NaN
#                      1592303469             NaN              NaN
#                      1592303470             NaN              NaN
#                      1592303471             NaN              NaN
#                      1592303472             NaN              NaN
#
#                                  system.cpu|system  system.cpu|nice  \
# host                 time_idx
# london.my-netdata.io 1592303468                NaN              NaN
#                      1592303469                NaN              NaN
#                      1592303470                NaN              NaN
#                      1592303471                NaN              NaN
#                      1592303472                NaN              NaN
#
#                                  system.cpu|iowait  system.load|load1  \
# host                 time_idx
# london.my-netdata.io 1592303468                NaN                NaN
#                      1592303469                NaN                NaN
#                      1592303470                NaN               0.03
#                      1592303471                NaN               0.03
#                      1592303472                NaN               0.03
#
#                                  system.load|load5  system.load|load15
# host                 time_idx
# london.my-netdata.io 1592303468                NaN                 NaN
#                      1592303469                NaN                 NaN
#                      1592303470               0.02                0.01
#                      1592303471               0.02                0.01
#                      1592303472               0.02                0.01
#
# [5 rows x 24 columns]

# %% [markdown]
# Lets have a look at some timings in pulling this data.

# %%
# %%timeit

df = get_data(hosts, charts, after, before)
# Out:
# 215 ms ± 26.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# If we wanted to pull data for all charts we can do something like this.

# %%
df = get_data('london.my-netdata.io', 'all', after, before)
print(df.shape)
df.head()
# Out:
# (66, 2091)
#             disk_qops.vda|operations  groups.pipes|ulog  \
# time_idx
# 1592303570                       0.0                1.0
# 1592303571                       0.0                1.0
# 1592303572                       0.0                1.0
# 1592303573                       0.0                1.0
# 1592303574                       0.0                1.0
#
#             groups.pipes|messagebus  groups.pipes|unscd  groups.pipes|bind  \
# time_idx
# 1592303570                      0.0                 0.0                1.0
# 1592303571                      0.0                 0.0                1.0
# 1592303572                      0.0                 0.0                1.0
# 1592303573                      0.0                 0.0                1.0
# 1592303574                      0.0                 0.0                1.0
#
#             groups.pipes|nogroup  groups.pipes|ntp  groups.pipes|postfix  \
# time_idx
# 1592303570                   0.0               0.0                   5.0
# 1592303571                   0.0               0.0                   5.0
# 1592303572                   0.0               0.0                   5.0
# 1592303573                   0.0               0.0                   5.0
# 1592303574                   0.0               0.0                   5.0
#
#             groups.pipes|mysql  groups.pipes|www-data  ...  \
# time_idx                                               ...
# 1592303570                 0.0                    0.0  ...
# 1592303571                 0.0                    0.0  ...
# 1592303572                 0.0                    0.0  ...
# 1592303573                 0.0                    0.0  ...
# 1592303574                 0.0                    0.0  ...
#
#             apps.major_faults|containers  apps.major_faults|ssh  \
# time_idx
# 1592303570                           NaN                    NaN
# 1592303571                           NaN                    NaN
# 1592303572                           NaN                    NaN
# 1592303573                           NaN                    NaN
# 1592303574                           NaN                    NaN
#
#             apps.major_faults|time apps.major_faults|named  \
# time_idx
# 1592303570                     NaN                     NaN
# 1592303571                     NaN                     NaN
# 1592303572                     NaN                     NaN
# 1592303573                     NaN                     NaN
# 1592303574                     NaN                     NaN
#
#             apps.major_faults|cron  apps.major_faults|ksmd  \
# time_idx
# 1592303570                     NaN                     NaN
# 1592303571                     NaN                     NaN
# 1592303572                     NaN                     NaN
# 1592303573                     NaN                     NaN
# 1592303574                     NaN                     NaN
#
#             apps.major_faults|system  apps.major_faults|kernel  \
# time_idx
# 1592303570                       NaN                       NaN
# 1592303571                       NaN                       NaN
# 1592303572                       NaN                       NaN
# 1592303573                       NaN                       NaN
# 1592303574                       NaN                       NaN
#
#             apps.major_faults|other  apps.major_faults|build
# time_idx
# 1592303570                      NaN                     None
# 1592303571                      NaN                     None
# 1592303572                      NaN                     None
# 1592303573                      NaN                     None
# 1592303574                      NaN                     None
#
# [5 rows x 2091 columns]

# %%
df.describe()
# Out:
#        disk_qops.vda|operations  groups.pipes|ulog  groups.pipes|messagebus  \
# count                      66.0               66.0                     66.0
# mean                        0.0                1.0                      0.0
# std                         0.0                0.0                      0.0
# min                         0.0                1.0                      0.0
# 25%                         0.0                1.0                      0.0
# 50%                         0.0                1.0                      0.0
# 75%                         0.0                1.0                      0.0
# max                         0.0                1.0                      0.0
#
#        groups.pipes|unscd  groups.pipes|bind  groups.pipes|nogroup  \
# count                66.0               66.0                  66.0
# mean                  0.0                1.0                   0.0
# std                   0.0                0.0                   0.0
# min                   0.0                1.0                   0.0
# 25%                   0.0                1.0                   0.0
# 50%                   0.0                1.0                   0.0
# 75%                   0.0                1.0                   0.0
# max                   0.0                1.0                   0.0
#
#        groups.pipes|ntp  groups.pipes|postfix  groups.pipes|mysql  \
# count              66.0                  66.0                66.0
# mean                0.0                   5.0                 0.0
# std                 0.0                   0.0                 0.0
# min                 0.0                   5.0                 0.0
# 25%                 0.0                   5.0                 0.0
# 50%                 0.0                   5.0                 0.0
# 75%                 0.0                   5.0                 0.0
# max                 0.0                   5.0                 0.0
#
#        groups.pipes|www-data  ...  apps.major_faults|logs  \
# count                   66.0  ...                    60.0
# mean                     0.0  ...                     0.0
# std                      0.0  ...                     0.0
# min                      0.0  ...                     0.0
# 25%                      0.0  ...                     0.0
# 50%                      0.0  ...                     0.0
# 75%                      0.0  ...                     0.0
# max                      0.0  ...                     0.0
#
#        apps.major_faults|containers  apps.major_faults|ssh  \
# count                          60.0                   60.0
# mean                            0.0                    0.0
# std                             0.0                    0.0
# min                             0.0                    0.0
# 25%                             0.0                    0.0
# 50%                             0.0                    0.0
# 75%                             0.0                    0.0
# max                             0.0                    0.0
#
#        apps.major_faults|time  apps.major_faults|named  \
# count                    60.0                     60.0
# mean                      0.0                      0.0
# std                       0.0                      0.0
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        apps.major_faults|cron  apps.major_faults|ksmd  \
# count                    60.0                    60.0
# mean                      0.0                     0.0
# std                       0.0                     0.0
# min                       0.0                     0.0
# 25%                       0.0                     0.0
# 50%                       0.0                     0.0
# 75%                       0.0                     0.0
# max                       0.0                     0.0
#
#        apps.major_faults|system  apps.major_faults|kernel  \
# count                      60.0                      60.0
# mean                        0.0                       0.0
# std                         0.0                       0.0
# min                         0.0                       0.0
# 25%                         0.0                       0.0
# 50%                         0.0                       0.0
# 75%                         0.0                       0.0
# max                         0.0                       0.0
#
#        apps.major_faults|other
# count                     60.0
# mean                       0.0
# std                        0.0
# min                        0.0
# 25%                        0.0
# 50%                        0.0
# 75%                        0.0
# max                        0.0
#
# [8 rows x 1973 columns]
